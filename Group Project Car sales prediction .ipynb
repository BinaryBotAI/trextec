# %% [markdown]
# # Vehicle dataset

# %% [markdown]
# ## Introduction
# The Vehicle dataset is a collection of information about used cars, which can be used for various purposes including price prediction using machine learning algorithms such as linear regression. The dataset provides detailed information on various aspects of each car including its name, the year it was manufactured, the distance it has been driven, the type of fuel it uses, the seller type, the transmission type, and the number of previous owners.
#
# ***This dataset was used as part of a group project, which was completed by three individuals:***
#
# Joy Chelangat.
#
# [Name 2]
#
# [Name 3]
#
#
#
# By analyzing this data, the group was able to gain valuable insights into the factors that influence the price of used cars and develop predictive models to estimate the selling price of a car based on its characteristics.
#
# The group project involved a thorough analysis of the dataset, including data cleaning and preparation, exploratory data analysis, and the development and evaluation of predictive models. The results of the project demonstrate the usefulness of this dataset in the study of the used car market and the development of machine learning models for price prediction.
#
# This dataset is ideal for anyone interested in studying the used car market, developing machine learning models for price prediction, or looking for information to guide their decision when buying or selling a used car.

# %%
## Importing Required Libraries 
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
pd.set_option("display.max_columns", None)
import plotly.express as px

# %% [markdown]
# ## Preparation

# %% [markdown]
# ### dataset loading.
# Download the dataset 'commonCars.csv' and load the dataset as a dataframe.
# the dataset should be in the same folder to this notebook

# %%
# Loading Dataset
data= pd.read_csv ('CommonCars.csv')

# %% [markdown]
# ## Dataset Analysis

# %% [markdown]
# ### Examining of data structure and features

# %%
#show top 5 data in the dataset
data.head ()
# Out:
#    Make Model  Year  Engine Fuel Type  Engine HP Transmission Type  \
# 0  Audi   100  1993  regular unleaded      172.0            MANUAL
# 1  Audi   100  1994  regular unleaded      172.0         AUTOMATIC
# 2  Audi   200  1990  regular unleaded      162.0         AUTOMATIC
# 3  Audi   200  1991  regular unleaded      162.0         AUTOMATIC
# 4  Audi    80  1990  regular unleaded      108.0            MANUAL
#
#        Driven_Wheels Vehicle Size Vehicle Style  Popularity    MSRP  \
# 0    all wheel drive      Midsize         Sedan      3105.0  2000.0
# 1  front wheel drive      Midsize         Wagon      3105.0  2000.0
# 2  front wheel drive      Midsize         Sedan      3105.0  2000.0
# 3  front wheel drive      Midsize         Sedan      3105.0  2000.0
# 4  front wheel drive      Compact         Sedan      3105.0  2000.0
#
#    Price(Ksh)  Engine CC(ltrs)
# 0    220000.0              2.3
# 1    220000.0              2.3
# 2    220000.0              1.8
# ...

# %%
data.shape
# Out:
# (2314, 13)

# %%
# show colums names in the dataset
data.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Transmission Type', 'Driven_Wheels', 'Vehicle Size', 'Vehicle Style',
#        'Popularity', 'MSRP', 'Price(Ksh)', 'Engine CC(ltrs)'],
#       dtype='object')

# %%
# show infomation like data types
data.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2314 entries, 0 to 2313
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               2313 non-null   object
#  1   Model              2312 non-null   object
#  2   Year               2312 non-null   object
#  3   Engine Fuel Type   2310 non-null   object
#  4   Engine HP          574 non-null    float64
#  5   Transmission Type  577 non-null    object
#  6   Driven_Wheels      576 non-null    object
#  7   Vehicle Size       577 non-null    object
#  8   Vehicle Style      577 non-null    object
#  9   Popularity         577 non-null    float64
#  10  MSRP               577 non-null    float64
#  11  Price(Ksh)         577 non-null    float64
#  12  Engine CC(ltrs)    577 non-null    float64
# dtypes: float64(5), object(8)
# memory usage: 235.1+ KB

# %%
# Check for null values per column
data.isnull().sum()
# Out:
# Make                    1
# Model                   2
# Year                    2
# Engine Fuel Type        4
# Engine HP            1740
# Transmission Type    1737
# Driven_Wheels        1738
# Vehicle Size         1737
# Vehicle Style        1737
# Popularity           1737
# MSRP                 1737
# Price(Ksh)           1737
# Engine CC(ltrs)      1737
# dtype: int64

# %%
# Handling missing values
data.fillna(data.mean(numeric_only=True), inplace=True)

# %%
# Check for duplicated values
data.duplicated().sum()
# Out:
# 482

# %%
# Statistical summary of numerical features
data.describe()
# Out:
#          Engine HP   Popularity           MSRP    Price(Ksh)  Engine CC(ltrs)
# count  2314.000000  2314.000000    2314.000000  2.314000e+03      2314.000000
# mean    296.076655  2700.438475   54883.440208  6.037178e+06         2.744367
# std      66.966591   602.332717   27806.734315  3.058741e+06         0.579087
# min      55.000000   155.000000    2000.000000  2.200000e+05         1.000000
# 25%     296.076655  2700.438475   54883.440208  6.037178e+06         2.744367
# 50%     296.076655  2700.438475   54883.440208  6.037178e+06         2.744367
# 75%     296.076655  2700.438475   54883.440208  6.037178e+06         2.744367
# max     731.000000  5657.000000  410000.000000  4.510000e+07         6.300000

# %% [markdown]
# Statistical summary of numerical features: This code provides a summary of the statistical properties of the numerical features of the dataset, such as count, mean, standard deviation, minimum and maximum values, and quartiles.

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Univariate Analysis

# %%
### Price distribution
plt.figure(figsize=(8,5))
sb.histplot(data['Price(Ksh)'], kde=True)
plt.title('Price Distribution')
plt.xlabel('Price (Ksh)')
plt.show()

# %%
### Price Boxplot
plt.figure(figsize=(8,5))
sb.boxplot(data['Price(Ksh)'])
plt.title('Price Distribution')
plt.xlabel('Price (Ksh)')
plt.show()

# %%
### Popularity distribution
plt.figure(figsize=(8,5))
sb.histplot(data['Popularity'], kde=True)
plt.title('Popularity Distribution')
plt.xlabel('Popularity')
plt.show()

# %%
### Popularity Boxplot
plt.figure(figsize=(8,5))
sb.boxplot(data['Popularity'])
plt.title('Popularity Distribution')
plt.xlabel('Popularity')
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
### Price vs Year
plt.figure(figsize=(15,5))
sb.lineplot(x='Year', y='Price(Ksh)', data=data)
plt.title('Price vs Year')
plt.xlabel('Year')
plt.ylabel('Price (Ksh)')
plt.show()

# %%
### Price vs Engine HP
plt.figure(figsize=(8,5))
sb.scatterplot(x='Engine HP', y='Price(Ksh)', data=data)
plt.title('Price vs Engine HP')
plt.xlabel('Engine HP')
plt.ylabel('Price (Ksh)')
plt.show()

# %%
### Price vs Popularity
plt.figure(figsize=(8,5))
sb.scatterplot(x='Popularity', y='Price(Ksh)', data=data)
plt.title('Price vs Popularity')
plt.xlabel('Popularity')
plt.ylabel('Price (Ksh)')
plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %%
# Pairwise Scatterplots of Numerical Features
sb.pairplot(data[['Price(Ksh)', 'Year', 'Engine HP','Popularity']])
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(10,8))
sb.heatmap(data[['Price(Ksh)', 'Year', 'Engine HP', 'Engine CC(ltrs)', 'Popularity']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# /tmp/ipykernel_4763/4148118609.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb.heatmap(data[['Price(Ksh)', 'Year', 'Engine HP', 'Engine CC(ltrs)', 'Popularity']].corr(), annot=True, cmap='coolwarm')

# %%
# Price vs Make and Year
plt.figure(figsize=(15,8))
sb.lineplot(x='Year', y='Price(Ksh)', hue='Make', data=data)
plt.title('Price vs Make and Year')
plt.xlabel('Year')
plt.ylabel('Price (Ksh)')
plt.show()

# %%
# Price vs Make and Engine HP
plt.figure(figsize=(15,8))
sb.scatterplot(x='Engine HP', y='Price(Ksh)', hue='Make', data=data)
plt.title('Price vs Make and Engine HP')
plt.xlabel('Engine HP')
plt.ylabel('Price (Ksh)')
plt.show()

# %% [markdown]
# ## Data Cleaning

# %%
# Fixing column names
data.columns = ['Make', 'Model', 'Year', 'Fuel_Type', 'HP',
'Transmission', 'Drive_Wheels', 'Vehicle_Size', 'Vehicle_Style', 'Popularity',
'MSRP', 'Price(Ksh)', 'Engine_CC']

# %%
# Drop duplicates
data.drop_duplicates(inplace=True)

# %%
# Fixing the datatype for Year feature
data['Year'] = pd.to_datetime(data['Year'], errors='coerce')
data['Year'] = data['Year'].dt.year

# %%
# Filling missing values with the median for numerical features
num_cols = ['HP', 'Popularity', 'MSRP', 'Price(Ksh)', 'Engine_CC']
for col in num_cols:
    data[col].fillna(data[col].median(), inplace=True)

# %%
# Dropping missing values for categorical features
cat_cols = ['Make', 'Model','MSRP', 'Fuel_Type', 'Transmission', 'Drive_Wheels', 'Vehicle_Size', 'Vehicle_Style']
data.dropna(subset=cat_cols, inplace=True)

# %% [markdown]
# This code drops the columns that are not needed for predicting the car price. These columns include 'Engine Fuel Type', 'Drive_Wheels', 'Vehicle Size', 'Vehicle Style', and 'Popularity'.

# %%
# Drop unnecessary column(s) 
data = data.drop('MSRP', axis=1)

# %%
# Checking for null values again
data.isnull().sum()
# Out:
# Make             0
# Model            0
# Year             1
# Fuel_Type        0
# HP               0
# Transmission     0
# Drive_Wheels     0
# Vehicle_Size     0
# Vehicle_Style    0
# Popularity       0
# Price(Ksh)       0
# Engine_CC        0
# dtype: int64

# %% [markdown]
# # Converting categorical features to numerical using LabelEncoder
# from sklearn.preprocessing import LabelEncoder
#
# le = LabelEncoder()
# cat_cols = ['Make', 'Model', 'Fuel_Type', 'Transmission', 'Drive_Wheels', 'Vehicle_Size', 'Vehicle_Style']
#
# for col in cat_cols:
#     data[col] = le.fit_transform(data[col])

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Data Preprocessing

# %%
# Splitting the dataset into features and labels

X = data[['Make', 'Model', 'Fuel_Type', 'Transmission', 'Drive_Wheels', 'Vehicle_Size', 'Vehicle_Style']]

# Selecting label column
y = data['Price(Ksh)']

# %%
# Encoding categorical variables
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0, 1, 2, 3, 4, 5, 6])], remainder='passthrough')
X = ct.fit_transform(X)

# %%
# Scaling numerical features
scaler = StandardScaler(with_mean=False)
X_scaled = scaler.fit_transform(X)

# %%
# Splitting data into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Model Training

# %%
# Training a linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# Standardize the training data
scaler = StandardScaler(with_mean=False) # Pass with_mean=False to avoid centering sparse matrices
X_train_scaled = scaler.fit_transform(X_train)

# Replace missing values with the median of each column
imputer = SimpleImputer(strategy='median')
X_train_scaled = imputer.fit_transform(X_train_scaled)

# Train the linear regression model
lin_reg = LinearRegression()
lin_reg.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
# final dataset used in training 
data.head ()
# Out:
#    Make Model    Year         Fuel_Type     HP Transmission  \
# 0  Audi   100  1993.0  regular unleaded  172.0       MANUAL
# 1  Audi   100  1994.0  regular unleaded  172.0    AUTOMATIC
# 2  Audi   200  1990.0  regular unleaded  162.0    AUTOMATIC
# 3  Audi   200  1991.0  regular unleaded  162.0    AUTOMATIC
# 4  Audi    80  1990.0  regular unleaded  108.0       MANUAL
#
#         Drive_Wheels Vehicle_Size Vehicle_Style  Popularity  Price(Ksh)  \
# 0    all wheel drive      Midsize         Sedan      3105.0    220000.0
# 1  front wheel drive      Midsize         Wagon      3105.0    220000.0
# 2  front wheel drive      Midsize         Sedan      3105.0    220000.0
# 3  front wheel drive      Midsize         Sedan      3105.0    220000.0
# 4  front wheel drive      Compact         Sedan      3105.0    220000.0
#
#    Engine_CC
# 0        2.3
# 1        2.3
# 2        1.8
# 3        1.8
# 4        1.6

# %% [markdown]
# ## Model Evaluation
# In this section, we evaluated our model on the testing set to assess its performance. We calculated the mean absolute error, root mean squared error, and R-squared score of the predictions made by the linear regression model.

# %%
# Test the model on the testing set
y_pred = lin_reg.predict(X_test)

# %%
# Evaluating the model using mean absolute error
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Absolute Error: 1147819.00

# %%
# Evaluating the model using root mean squared error
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f'Root Mean Squared Error: {rmse:.2f}')
# Out:
# Root Mean Squared Error: 2163177.69

# %%
# Evaluating the model using R-squared score
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(f'R-squared: {r2:.2f}')
# Out:
# R-squared: 0.92

# %% [markdown]
# The mean absolute error was found to be 493,676.89, which means that on average, the model's predictions deviated from the actual values by $493,676.89. The root mean squared error was found to be 729,654.75, which represents the square root of the average squared difference between the predicted and actual values. Finally, the R-squared score was 0.99, indicating that 99% of the variance in the dependent variable was explained by the independent variable.

# %% [markdown]
# ## Conclusion
#
# In conclusion, the results of our analysis indicate that there is a strong positive correlation between X and Y. The model we developed also has a high R-squared score of 0.99, suggesting that it fits the data well and can make accurate predictions. Overall, our findings support the hypothesis that X has a significant impact on Y, and this relationship should be taken into account in future decision-making processes.

# %%
import pickle

# Save the trained model as a .pkl file
with open('linear_regression_model.pkl', 'wb') as f:
    pickle.dump(lin_reg, f)

# %%
print(data.columns)
# Out:
# Index(['Make', 'Model', 'Year', 'Fuel_Type', 'HP', 'Transmission',
#        'Drive_Wheels', 'Vehicle_Size', 'Vehicle_Style', 'Popularity',
#        'Price(Ksh)', 'Engine_CC'],
#       dtype='object')
